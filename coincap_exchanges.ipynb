# %% [markdown]
# <a href="https://colab.research.google.com/github/msaltan/DataBootcamp2025/blob/main/coincap_exchanges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
url = 'https://api.coincap.io/v2/exchanges'
response = requests.get(url)
if response.ok:
    df = pd.read_json(response.text)
    print(df)
else:
    print("Failed to retrieve data. Status code:", response.status_code)
# Out:
#                                                  data               timestamp
# 0   {'exchangeId': 'binance', 'name': 'Binance', '... 2025-01-17 17:03:04.980
# 1   {'exchangeId': 'gdax', 'name': 'Coinbase Pro',... 2025-01-17 17:03:04.980
# 2   {'exchangeId': 'crypto', 'name': 'Crypto.com E... 2025-01-17 17:03:04.980
# 3   {'exchangeId': 'whitebit', 'name': 'WhiteBIT',... 2025-01-17 17:03:04.980
# 4   {'exchangeId': 'digifinex', 'name': 'DigiFinex... 2025-01-17 17:03:04.980
# ..                                                ...                     ...
# 95  {'exchangeId': 'kuna', 'name': 'Kuna', 'rank':... 2025-01-17 17:03:04.980
# 96  {'exchangeId': 'mercatox', 'name': 'Mercatox',... 2025-01-17 17:03:04.980
# 97  {'exchangeId': 'mxc-com', 'name': 'MXC.COM', '... 2025-01-17 17:03:04.980
# 98  {'exchangeId': 'okcoin', 'name': 'OkCoin', 'ra... 2025-01-17 17:03:04.980
# 99  {'exchangeId': 'okex', 'name': 'Okex', 'rank':... 2025-01-17 17:03:04.980
#
# [100 rows x 2 columns]
# ...

# %%
import json
df_data = pd.json_normalize(df['data'])
df_data
# Out:
#    exchangeId                 name rank  \
# 0     binance              Binance    1
# 1        gdax         Coinbase Pro    2
# 2      crypto  Crypto.com Exchange    3
# 3    whitebit             WhiteBIT    4
# 4   digifinex            DigiFinex    5
# ..        ...                  ...  ...
# 95       kuna                 Kuna   90
# 96   mercatox             Mercatox   91
# 97    mxc-com              MXC.COM   92
# 98     okcoin               OkCoin   93
# 99       okex                 Okex   94
#
#                          percentTotalVolume                     volumeUsd  \
# 0   35.258751604310591064000000000000000000  15417556047.8737324391603909
# 1   10.467743816593758531000000000000000000   4577218978.0930147535295583
# 2    9.341904654439430908000000000000000000   4084924509.5252884517634979
# 3    7.088287885715091917000000000000000000   3099487950.9039736477151094
# 4    4.918657524134644128000000000000000000   2150776037.3844491332139628
# ...

# %%
df_data.to_csv('exchanges.csv', index=False)

# %%
df.to_json('exchanges1.json' )
df_data.to_json('exchanges2.json' )

# %%
df_data.to_xml('exchanges.xml', index=False)

# %%
df_data.to_parquet('exchanges.parquet', index=False)

# %%
df_data.shape
# Out:
# (100, 9)

# %%
df_data.describe()
# Out:
#             updated
# count  1.000000e+02
# mean   1.490336e+12
# std    6.044485e+11
# min    0.000000e+00
# 25%    1.728017e+12
# 50%    1.737133e+12
# 75%    1.737133e+12
# max    1.737133e+12

# %%
df_data.dtypes
# Out:
# exchangeId            object
# name                  object
# rank                  object
# percentTotalVolume    object
# volumeUsd             object
# tradingPairs          object
# socket                object
# exchangeUrl           object
# updated                int64
# dtype: object

# %%
# !pip install jupysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# !pip install duckdb-engine
# %sql duckdb://
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.0 MB/s eta 0:00:00
# ...
# Connecting to 'duckdb://'

# %%
# %%sql
# WITH exchange_data as (
#     SELECT UNNEST(data) as data
#     FROM read_json('https://api.coincap.io/v2/exchanges')
# )
# SELECT
# regexp_replace(json_extract(data, '$.exchangeId')::VARCHAR, '"', '', 'g') AS id,
# regexp_replace(json_extract(data, '$.name')::VARCHAR, '"', '', 'g') AS name,
# json_extract(data, '$.rank')::INTEGER AS rank,
# json_extract(data, '$.percentTotalVolume')::DOUBLE AS percentTotalVolume,
# json_extract(data, '$.volumeUsd')::DOUBLE AS volumeUsd,
# json_extract(data, '$.tradingPairs')::INTEGER AS tradingPairs,
# json_extract(data, '$.socket')::BOOLEAN AS socket,
# regexp_replace(json_extract(data, '$.exchangeUrl')::VARCHAR, '"', '', 'g') AS nexchangeUrl,
# to_timestamp(json_extract(data, '$.updated')::BIGINT/1000) AS updated
# FROM exchange_data
# Out:
# Running query in 'duckdb://'
# +-----------+---------------------+------+--------------------+--------------------+--------------+--------+-------------------------------------------------------------------+----------------------------------+
# |     id    |         name        | rank | percentTotalVolume |     volumeUsd      | tradingPairs | socket |                            nexchangeUrl                           |             updated              |
# +-----------+---------------------+------+--------------------+--------------------+--------------+--------+-------------------------------------------------------------------+----------------------------------+
# |  binance  |       Binance       |  1   | 38.44870728735388  | 18353042174.671215 |     652      |  True  |   <a href=https://www.binance.com/>https://www.binance.com/</a>   | 2025-01-18 07:18:47.920000+00:00 |
# ...
